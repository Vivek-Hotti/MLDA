# %% [markdown]
# ## <font color='green'>Handling Missing Values </font>

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading Dataset

# %%
data = pd.read_csv('C:\\Users\\Vivek hotti\\Desktop\\Practice\\ML DA\\melb_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
# ...

# %% [markdown]
# ### Data Description

# %%
data.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %% [markdown]
# ### Data Information

# %%
data.isnull().sum()
# We can see sum of null values present in each column
# Out:
# Unnamed: 0           0
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          3469
# Bathroom          3471
# Car               3576
# Landsize          4793
# BuildingArea     10634
# YearBuilt         9438
# CouncilArea       6163
# Lattitude         3332
# Longtitude        3332
# Regionname           1
# Propertycount        1
# dtype: int64

# %% [markdown]
# #### <font color='blue'>So as we can see, close to 13 columns have Null values and that too in thousands. So dropping those columns or rows would not be feasible for us as we would be loosing on more important data that will help the system in prediction. So hence we use the fillna() function.</font>

# %% [markdown]
# ## <font color='green'>Approach 1: Using the fillna() method </font>

# %% [markdown]
# #### <b>The fillna() function is used only when all the NULL values in every column has to be filled with the same data / value.</b>
#
# As you will see in this example, we have filled every Null value with the number <b>999</b>

# %%
# seprately selecting and holding data that has got NULL Values.
cols = ['Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname', 'Propertycount']

# %%
data[cols].isnull().sum()
# Out:
# Distance             1
# Postcode             1
# Bedroom2          3469
# Bathroom          3471
# Car               3576
# Landsize          4793
# BuildingArea     10634
# YearBuilt         9438
# CouncilArea       6163
# Lattitude         3332
# Longtitude        3332
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
data[cols].head()
# Out:
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5    3067.0       2.0       1.0  1.0     202.0           NaN
# 1       2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 2       2.5    3067.0       3.0       2.0  0.0     134.0         150.0
# 3       2.5    3067.0       3.0       2.0  1.0      94.0           NaN
# 4       2.5    3067.0       3.0       1.0  2.0     120.0         142.0
#
#    YearBuilt CouncilArea  Lattitude  Longtitude             Regionname  \
# 0        NaN       Yarra   -37.7996    144.9984  Northern Metropolitan
# 1     1900.0       Yarra   -37.8079    144.9934  Northern Metropolitan
# 2     1900.0       Yarra   -37.8093    144.9944  Northern Metropolitan
# 3        NaN       Yarra   -37.7969    144.9969  Northern Metropolitan
# 4     2014.0       Yarra   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# 2         4019.0
# 3         4019.0
# 4         4019.0

# %%
data[cols].describe()
# Out:
#            Distance      Postcode      Bedroom2      Bathroom           Car  \
# count  18395.000000  18395.000000  14927.000000  14925.000000  14820.000000
# mean      10.389986   3107.140147      2.913043      1.538492      1.615520
# std        6.009050     95.000995      0.964641      0.689311      0.955916
# min        0.000000   3000.000000      0.000000      0.000000      0.000000
# 25%        6.300000   3046.000000      2.000000      1.000000      1.000000
# 50%        9.700000   3085.000000      3.000000      1.000000      2.000000
# 75%       13.300000   3149.000000      3.000000      2.000000      2.000000
# max       48.100000   3978.000000     20.000000      8.000000     10.000000
#
#             Landsize  BuildingArea    YearBuilt     Lattitude    Longtitude  \
# count   13603.000000   7762.000000  8958.000000  15064.000000  15064.000000
# mean      558.116371    151.220219  1965.879996    -37.809849    144.996338
# ...

# %%
a = data[cols].fillna(value = 999)

# %%
a.head(5)
# Out:
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5    3067.0       2.0       1.0  1.0     202.0         999.0
# 1       2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 2       2.5    3067.0       3.0       2.0  0.0     134.0         150.0
# 3       2.5    3067.0       3.0       2.0  1.0      94.0         999.0
# 4       2.5    3067.0       3.0       1.0  2.0     120.0         142.0
#
#    YearBuilt CouncilArea  Lattitude  Longtitude             Regionname  \
# 0      999.0       Yarra   -37.7996    144.9984  Northern Metropolitan
# 1     1900.0       Yarra   -37.8079    144.9934  Northern Metropolitan
# 2     1900.0       Yarra   -37.8093    144.9944  Northern Metropolitan
# 3      999.0       Yarra   -37.7969    144.9969  Northern Metropolitan
# 4     2014.0       Yarra   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# 2         4019.0
# 3         4019.0
# 4         4019.0

# %%
a.isnull().sum()
# Out:
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# ## <font color='green'>Approach 2: Using Imputer </font>

# %% [markdown]
# Strategy to handle missing values :
# - mean
# - median
# - most_frequent (mode)

# %%
from sklearn.impute import SimpleImputer

imputer_mean = SimpleImputer(missing_values = np.nan, strategy = "mean")
imputer_median = SimpleImputer(missing_values = np.nan, strategy = "median")

# %% [markdown]
# ### I am still to learn the usage of Imputer. Abandoning the same and will learn as will update.
